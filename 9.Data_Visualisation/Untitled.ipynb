# %%
import pandas as pd
import numpy as np
import glob
import re
import os

# %%
s = "world-happiness-report/2015.csv"
s = re.findall(r'[0-9]+',s)[0]
print(s)
# Out:
# 2015

# %%
file_names = glob.glob('world-happiness-report/*.csv')
li = []
for filename in file_names:
    temp = pd.read_csv(filename)
    temp["Year"] =  re.findall(r'[0-9]+',filename)[0]
    li.append(temp)
df = pd.concat(li)
# Out:
# /Users/paragpradhan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys

# %%
df.tail()
# Out:
#                       Country  Dystopia Residual  Economy (GDP per Capita)  \
# 150                    Rwanda           0.540061                  0.368746
# 151                     Syria           1.061574                  0.777153
# 152                  Tanzania           0.621130                  0.511136
# 153                   Burundi           1.683024                  0.091623
# 154  Central African Republic           2.066005                  0.000000
#
#        Family   Freedom  Generosity  Happiness Rank  Happiness Score  \
# 150  0.945707  0.581844    0.252756             151            3.471
# 151  0.396103  0.081539    0.493664             152            3.462
# 152  1.041990  0.390018    0.354256             153            3.349
# 153  0.629794  0.059901    0.204435             154            2.905
# 154  0.000000  0.270842    0.280876             155            2.693
#
#      Health (Life Expectancy)  Lower Confidence Interval Region  \
# ...
